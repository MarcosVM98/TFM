# %% [markdown]
# In this notebook we make models for clusters with unimodal fire season.
#
# We use the functions defined in the file "scripts/modelling_functions_new.R".

# %%
setwd("..")

# %%
source("scripts/modelling_functions_new.R")
# Out:
# Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Loading required package: sp
# Warning message:
# "package 'sp' was built under R version 3.6.3"Loading required package: magrittr
# Warning message:
# "package 'magrittr' was built under R version 3.6.3"
# Attaching package: 'magrittr'
#
# The following object is masked from 'package:tidyr':
#
#     extract
#
# Warning message:
# "package 'caret' was built under R version 3.6.3"Loading required package: lattice
# Warning message:
# "package 'lattice' was built under R version 3.6.3"Loading required package: ggplot2
# Warning message:
# "package 'randomForest' was built under R version 3.6.3"randomForest 4.6-14
# ...

# %%
# Data required
load('fireSeasonPer75_def.Rdata', verbose = T)
load("data/ba_mon_time_series_masked.Rdata", verbose = T)
load("data/ba_mon_clim_masked_df.Rdata", verbose = T)
load('corrDfAnnualClus.Rdata', verbose = T)
load('corrDfAnnualClusLag1.Rdata', verbose = T)
load('corrDfAnnualClusLag2.Rdata', verbose = T)
load('corrDfAnnualClusLag3.Rdata', verbose = T)
# Out:
# Loading objects:
#   fireSeasonPer75_def
# Loading objects:
#   masked_coords
#   dates
#   masked_ba_series
# Loading objects:
#   df_masked
#   masked_coords
# Loading objects:
#   corr.df
# Loading objects:
#   corr.df.lag.1
# Loading objects:
#   corr.df.lag.2
# Loading objects:
#   corr.df.lag.3

# %% [markdown]
# # Climate indexes data loading

# %%
nina34 = read.table("CPC/nina34.anom.data.txt", skip = 3, nrows = 72)
colnames(nina34) = c("Year", 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')
nina34[,-1] = (nina34[,-1] - mean(as.matrix(nina34[32:61,-1]))) / sd(as.matrix(nina34[32:61,-1]))

# %%
nao = read.table("CPC/nao_index.tim.txt", skip = 8, header = T)
nao <- nao %>% spread(MONTH,INDEX)
colnames(nao) = c("Year", 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')

# %%
poleur = read.table("CPC/poleur_index.tim", skip = 8, header = T)
poleur <- poleur %>% spread(MONTH,INDEX)
colnames(poleur) = c("Year", 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')

# %%
ea = read.table("CPC/ea_index.tim.txt", skip = 8, header = T)
ea <- ea %>% spread(MONTH,INDEX)
colnames(ea) = c("Year", 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')

# %%
eawr = read.table("CPC/eawr_index.tim.txt", skip = 8, header = T)
eawr <- eawr %>% spread(MONTH,INDEX)
colnames(eawr) = c("Year", 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')

# %%
pna = read.table("CPC/pna_index.tim.txt", skip = 8, header = T)
pna <- pna %>% spread(MONTH,INDEX)
colnames(pna) = c("Year", 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')

# %%
scand = read.table("CPC/scand_index.tim.txt", skip = 8, header = T)
scand <- scand %>% spread(MONTH,INDEX)
colnames(scand) = c("Year", 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')

# %%
wp = read.table("CPC/wp_index.tim.txt", skip = 8, header = T)
wp <- wp %>% spread(MONTH,INDEX)
colnames(wp) = c("Year", 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')

# %% [markdown]
# # Linear model for some particular clusters
#
# ## Biome 2, cluster 4
#
# This one has a significant correlation of -0.5 with the 'ea' index. Red lines are the predicted ones.

# %%
t = lm.clus.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, corr.df, 
                 list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 2, 4)
# Out:
#         RMSE       bias      RVar cor.pvalue       cor       acc acc.t1
# cor 11.20223 0.01159078 0.2492008  0.1460115 0.3466051 0.6315789    0.5
#        acc.t2    acc.t3
# cor 0.6666667 0.7142857
# Plot with title "Observed vs predicted"

# %% [markdown]
# ## Biome 2, cluster 3
#
# This one has a significant correlation of 0.6 with the 'pna' index. Red lines are the predicted ones.

# %%
t = lm.clus.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, corr.df, 
                 list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 2, 3)
# Out:
#         RMSE      bias      RVar cor.pvalue       cor       acc    acc.t1
# cor 8.211024 0.0152052 0.3490131 0.04934211 0.4566976 0.5263158 0.3333333
#     acc.t2    acc.t3
# cor    0.5 0.7142857
# Plot with title "Observed vs predicted"

# %%
#series = data.frame(ba = df$df[,1], nina34 = df$df[,2], nao = df$df[,3], poleur = df$df[,4], ea = df$df[,5], eawr = df$df[,6],
                    #pna = df$df[,7], scand = df$df[,8], wp = df$df[,9])
#series
# save(series, file = 'seriesBioma2Cluster3.Rdata')

# %% [markdown]
# ## Biome 11, cluster 31
#
# This one has a significant correlation of -0.6 with the 'eawr' index. Red lines are the predicted ones.

# %%
t = lm.clus.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, corr.df, 
                 list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 11, 31)
# Out:
#         RMSE     bias      RVar cor.pvalue       cor       acc    acc.t1
# cor 83.97864 6.284733 0.4164586 0.02746366 0.5049073 0.4736842 0.3333333
#        acc.t2    acc.t3
# cor 0.3333333 0.7142857
# Plot with title "Observed vs predicted"

# %% [markdown]
# ## Biome 5, cluster 1
#
# This one has a significant correlation of -0.65 with the 'nina34' index. Red lines are the predicted ones.

# %%
t = lm.clus.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, corr.df, 
                 list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 5, 1)
# Out:
#        RMSE       bias      RVar cor.pvalue       cor       acc    acc.t1
# cor 18.4422 0.09692525 0.5018555 0.01843458 0.5484522 0.7777778 0.8333333
#        acc.t2    acc.t3
# cor 0.6666667 0.8333333
# Plot with title "Observed vs predicted"

# %% [markdown]
# # Models for all the clusters
#
# ## With no persistence

# %%
lm.list <- lm.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, corr.df, 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), mode = 'unimodal')

# %%
lm.list$results
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1       1        6.839691 0.011179855 0.2659278 0.14712217
# 3   1      2       0              NA          NA        NA         NA
# 4   1      3       0              NA          NA        NA         NA
# 5   1      4      NA              NA          NA        NA         NA
# 6   1      5      NA              NA          NA        NA         NA
# 7   1      6       1       15.426281 0.006749490 0.3417525 0.05547053
# 8   1      7       1       23.746449 0.021355105 0.3450909 0.08903802
# 9   1      8       0              NA          NA        NA         NA
# 10  1      9       0              NA          NA        NA         NA
# 11  1     10       2       16.815977 0.007856959 0.4794496 0.05568766
# 12  1     11       0              NA          NA        NA         NA
# 13  1     12      NA              NA          NA        NA         NA
# ...

# %%
rf.list <- rf.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, corr.df, list(nina34, nao, poleur, ea, eawr, pna, scand, wp),
                  mode = 'unimodal')

# %%
rf.list$results
# Out:
#     biome cluster rf.Ntree rf.RMSE   rf.bias     rf.RVar    rf.cor.pvalue
# 2   1      1      120       6.861168 0.011065635 0.13715055 0.16938389
# 3   1      2      100      10.238028 0.008469694 0.14010102 0.35833820
# 4   1      3      140      27.135664 0.029564405 0.06961403 0.23391577
# 5   1      4       NA             NA          NA         NA         NA
# 6   1      5       NA             NA          NA         NA         NA
# 7   1      6       40      16.546418 0.006700425 0.11808657 0.28987962
# 8   1      7      100      27.937151 0.021659469 0.07480232 0.29624616
# 9   1      8       20      15.610951 0.009327377 0.11062342 0.13285147
# 10  1      9       20      13.453036 0.007072023 0.14379171 0.39168779
# 11  1     10       40      18.326921 0.007756458 0.15550033 0.54780484
# 12  1     11      200      22.529648 0.028681222 0.12602394 0.35187103
# 13  1     12       NA             NA          NA         NA         NA
# ...

# %%
knn.list <- knn.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, corr.df, list(nina34, nao, poleur, ea, eawr, pna, scand, wp),
                  mode = 'unimodal')

# %%
knn.list$results
# Out:
#     biome cluster knn.RMSE  knn.bias    knn.RVar  knn.cor.pvalue knn.cor
# 2   1      1      10.213884 0.011030013 1.4712073 0.417110708     0.19773313
# 3   1      2      17.229993 0.008604094 1.4608101 0.638321007    -0.11530325
# 4   1      3      31.430387 0.029108360 0.8730840 0.621507385     0.12106698
# 5   1      4             NA          NA        NA          NA             NA
# 6   1      5             NA          NA        NA          NA             NA
# 7   1      6      17.122205 0.006453111 1.2860722 0.007757324     0.59060297
# 8   1      7      36.448259 0.018741244 0.5368383 0.479806118    -0.17260327
# 9   1      8      17.198856 0.008862631 0.5362195 0.866684442     0.04129990
# 10  1      9      22.761157 0.006860229 1.5280014 0.602418005    -0.12768611
# 11  1     10      27.173134 0.007763237 1.0152797 0.560190752    -0.13855450
# 12  1     11      30.971745 0.030097351 0.9625408 0.375647638    -0.21547531
# ...

# %%
table = cbind(lm.list$results, rf.list$results[,-c(1,2)], knn.list$results[,-c(1,2)])
table
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1       1        6.839691 0.011179855 0.2659278 0.14712217
# 3   1      2       0              NA          NA        NA         NA
# 4   1      3       0              NA          NA        NA         NA
# 5   1      4      NA              NA          NA        NA         NA
# 6   1      5      NA              NA          NA        NA         NA
# 7   1      6       1       15.426281 0.006749490 0.3417525 0.05547053
# 8   1      7       1       23.746449 0.021355105 0.3450909 0.08903802
# 9   1      8       0              NA          NA        NA         NA
# 10  1      9       0              NA          NA        NA         NA
# 11  1     10       2       16.815977 0.007856959 0.4794496 0.05568766
# 12  1     11       0              NA          NA        NA         NA
# 13  1     12      NA              NA          NA        NA         NA
# ...

# %%
save(table, file = 'ModelData/models_results_per_cluster_without_delta_no_persistence.Rdata')
#model.no.deltas.noP = list('lm' = lm.list, 'rf' = rf.list, 'knn' = knn.list)
#save(model.no.deltas.noP, file = 'ModelData/models_without_delta_no_persistence')

# %%
# Clusters that have a linear, a random forest and a knn models
table1 <- table[-which(is.na(table$lm.RMSE)),]
table1
# Out:
#     biome cluster lm.Npred lm.RMSE    lm.bias     lm.RVar   lm.cor.pvalue
# 2    1     1      1          6.839691 0.011179855 0.2659278 0.1471221653
# 7    1     6      1         15.426281 0.006749490 0.3417525 0.0554705349
# 8    1     7      1         23.746449 0.021355105 0.3450909 0.0890380196
# 11   1    10      2         16.815977 0.007856959 0.4794496 0.0556876635
# 14   1    13      1         21.262815 0.015197798 0.3111555 0.0928447033
# 16   2     1      1         14.947212 0.035852251 0.3405630 0.1381940439
# 18   2     3      1          8.211024 0.015205198 0.3490131 0.0493421131
# 19   2     4      1         11.202225 0.011590783 0.2492008 0.1460115362
# 20   2     5      1         11.687553 0.013299035 0.3998817 0.0274744018
# 21   2     6      1         28.895585 0.032670894 0.3068498 0.0721124006
# 27   4     3      1         17.133059 0.004169522 0.4632197 0.0123245640
# 29   5     1      1         18.442202 0.096925254 0.5018555 0.0184345763
# ...

# %%
colMeans(table1[,-c(1,2,3,12)])
# Out:
#        lm.RMSE        lm.bias        lm.RVar  lm.cor.pvalue         lm.cor
#     36.8154362      0.7613807      0.3676816      0.1194960      0.4145736
#         lm.acc      lm.acc.t1      lm.acc.t2       rf.Ntree        rf.RMSE
#      0.4923773      0.5215947      0.3449612     79.0697674     38.7194734
#        rf.bias        rf.RVar  rf.cor.pvalue         rf.cor         rf.acc
#      0.7583679      0.1366206      0.4119436      0.2038028      0.3958860
#      rf.acc.t1      rf.acc.t2      rf.acc.t3       knn.RMSE       knn.bias
#      0.3898117      0.2945736      0.4889258     52.9233535      0.6633839
#       knn.RVar knn.cor.pvalue        knn.cor        knn.acc     knn.acc.t1
#      0.9548034      0.4498502      0.1090925      0.3808922      0.3139535
#     knn.acc.t2     knn.acc.t3
#      0.3333333      0.4800664

# %% [markdown]
# ## With 1-month persistence

# %%
#for (i in 3:dim(corr.df.lag.1)[2]){
 #   names(corr.df.lag.1)[names(corr.df.lag.1) == names(corr.df.lag.1)[i]] <- paste(names(corr.df.lag.1)[i], '.lag1', sep = '')
#}
#names(corr.df.lag.1)

lm.list <- lm.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), mode = 'unimodal', t = 1)

# %%
lm.list$results
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1       1        6.839691 0.011179855 0.2659278 0.14712217
# 3   1      2       1        9.412035 0.008465760 0.2897392 0.06309536
# 4   1      3       0              NA          NA        NA         NA
# 5   1      4      NA              NA          NA        NA         NA
# 6   1      5      NA              NA          NA        NA         NA
# 7   1      6       2       16.172826 0.006771533 0.3950600 0.09577408
# 8   1      7       2       22.871206 0.021323256 0.4858866 0.03546016
# 9   1      8       0              NA          NA        NA         NA
# 10  1      9       0              NA          NA        NA         NA
# 11  1     10       2       16.815977 0.007856959 0.4794496 0.05568766
# 12  1     11       0              NA          NA        NA         NA
# 13  1     12      NA              NA          NA        NA         NA
# ...

# %%
rf.list <- rf.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)]),
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp),
                  mode = 'unimodal', t = 1)

# %%
rf.list$results
# Out:
#     biome cluster rf.Ntree rf.RMSE   rf.bias     rf.RVar    rf.cor.pvalue
# 2   1      1       60       7.035524 0.011124341 0.07489891 0.37517820
# 3   1      2      120       9.982157 0.008497827 0.09474518 0.25390093
# 4   1      3      200      26.489993 0.028981833 0.05443443 0.30642587
# 5   1      4       NA             NA          NA         NA         NA
# 6   1      5       NA             NA          NA         NA         NA
# 7   1      6       60      16.384582 0.006649424 0.07640206 0.23563913
# 8   1      7       10      27.101894 0.021639482 0.16128733 0.92109484
# 9   1      8       80      15.735118 0.009232734 0.09370395 0.06351485
# 10  1      9      200      14.649724 0.007073272 0.04300229 0.19923713
# 11  1     10       20      17.092813 0.007621561 0.12621123 0.15272538
# 12  1     11       80      22.517579 0.028854026 0.10622020 0.25294514
# 13  1     12       NA             NA          NA         NA         NA
# ...

# %%
knn.list <- knn.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)]),
                    list(nina34, nao, poleur, ea, eawr, pna, scand, wp),
                  mode = 'unimodal', t = 1)

# %%
knn.list$results
# Out:
#     biome cluster knn.RMSE  knn.bias    knn.RVar   knn.cor.pvalue knn.cor
# 2   1      1      10.770124 0.011065450 1.7562304  0.4181940558    0.197282735
# 3   1      2      17.925223 0.008761974 1.6133456  0.6607326325   -0.107709469
# 4   1      3      37.760384 0.027192905 0.9756022  0.4828617315   -0.171422546
# 5   1      4             NA          NA        NA            NA             NA
# 6   1      5             NA          NA        NA            NA             NA
# 7   1      6      18.193925 0.006361864 1.2515751  0.0156524009    0.545721721
# 8   1      7      34.840512 0.020566385 0.8312572  0.9665853563   -0.010310287
# 9   1      8      18.940791 0.009042414 0.7268478  0.6458821913   -0.112730304
# 10  1      9      27.892585 0.007411911 1.7074467  0.0225120477   -0.519893421
# 11  1     10      29.193797 0.007520672 1.0745135  0.2741479310   -0.256937176
# 12  1     11      31.240443 0.031210343 0.8322007  0.2838843743   -0.259214264
# ...

# %%
table = cbind(lm.list$results, rf.list$results[,-c(1,2)], knn.list$results[,-c(1,2)])
table
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1       1        6.839691 0.011179855 0.2659278 0.14712217
# 3   1      2       1        9.412035 0.008465760 0.2897392 0.06309536
# 4   1      3       0              NA          NA        NA         NA
# 5   1      4      NA              NA          NA        NA         NA
# 6   1      5      NA              NA          NA        NA         NA
# 7   1      6       2       16.172826 0.006771533 0.3950600 0.09577408
# 8   1      7       2       22.871206 0.021323256 0.4858866 0.03546016
# 9   1      8       0              NA          NA        NA         NA
# 10  1      9       0              NA          NA        NA         NA
# 11  1     10       2       16.815977 0.007856959 0.4794496 0.05568766
# 12  1     11       0              NA          NA        NA         NA
# 13  1     12      NA              NA          NA        NA         NA
# ...

# %%
# Clusters that have a linear, a random forest and a knn models
table1 <- table[-which(is.na(table$lm.RMSE)),]
table1
# Out:
#     biome cluster lm.Npred lm.RMSE    lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1      1         6.839691  0.011179855 0.2659278 0.1471221653
# 3   1      2      1         9.412035  0.008465760 0.2897392 0.0630953582
# 7   1      6      2        16.172826  0.006771533 0.3950600 0.0957740809
# 8   1      7      2        22.871206  0.021323256 0.4858866 0.0354601634
# 11  1     10      2        16.815977  0.007856959 0.4794496 0.0556876635
# 14  1     13      1        21.262815  0.015197798 0.3111555 0.0928447033
# 16  2      1      2        14.747969  0.035788059 0.4210993 0.0931488095
# 18  2      3      2         8.454664  0.015193542 0.3687114 0.0727217230
# 19  2      4      2        12.869338  0.011497446 0.2216565 0.8706706908
# 20  2      5      2        12.539379  0.013342167 0.4725442 0.0631044675
# 21  2      6      2        28.949940  0.032768732 0.4075044 0.0580581986
# 27  4      3      3        17.786819  0.004162922 0.6534614 0.0132376905
# ...

# %%
colMeans(table1[,-c(1,2,3,12)])
# Out:
#        lm.RMSE        lm.bias        lm.RVar  lm.cor.pvalue         lm.cor
#    40.01317425     0.84800627     0.40917025     0.16286490     0.38982957
#         lm.acc      lm.acc.t1      lm.acc.t2       rf.Ntree        rf.RMSE
#     0.48105167     0.48907104     0.36065574    80.81967213    41.67111552
#        rf.bias        rf.RVar  rf.cor.pvalue         rf.cor         rf.acc
#     0.87915947     0.09212686     0.44548807     0.12773935     0.38585946
#      rf.acc.t1      rf.acc.t2      rf.acc.t3       knn.RMSE       knn.bias
#     0.38056206     0.31967213     0.44730679    55.10354982     0.72111961
#       knn.RVar knn.cor.pvalue        knn.cor        knn.acc     knn.acc.t1
#     0.91652204     0.46237536     0.06811204     0.36566485     0.30679157
#     knn.acc.t2     knn.acc.t3
#     0.30874317     0.46721311

# %%
table.lag.1 <- table
save(table.lag.1, file = 'ModelData/models_results_per_cluster_without_delta_lag1.Rdata')
#model.no.deltas.Lag.1 = list('lm' = lm.list, 'rf' = rf.list, 'knn' = knn.list)
#save(model.no.deltas.Lag.1, file = 'ModelData/models_without_delta_lag_1')

# %% [markdown]
# ## With 2-months persistence

# %%
#for (i in 3:dim(corr.df.lag.2)[2]){
 #   names(corr.df.lag.2)[names(corr.df.lag.2) == names(corr.df.lag.2)[i]] <- paste(names(corr.df.lag.2)[i], '.lag2', sep = '')
#}
#names(corr.df.lag.2)

lm.list <- lm.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), mode = 'unimodal', t = 2)

# %%
lm.list$results
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1       1        6.839691 0.011179855 0.2659278 0.147122165
# 3   1      2       2        9.362343 0.008462079 0.3504922 0.050994782
# 4   1      3       0              NA          NA        NA          NA
# 5   1      4      NA              NA          NA        NA          NA
# 6   1      5      NA              NA          NA        NA          NA
# 7   1      6       3       14.584997 0.006764675 0.5742464 0.013585201
# 8   1      7       3       23.442196 0.021424566 0.5132260 0.047067758
# 9   1      8       0              NA          NA        NA          NA
# 10  1      9       0              NA          NA        NA          NA
# 11  1     10       2       16.815977 0.007856959 0.4794496 0.055687664
# 12  1     11       0              NA          NA        NA          NA
# 13  1     12      NA              NA          NA        NA          NA
# ...

# %%
rf.list <- rf.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), mode = 'unimodal', t = 2)

# %%
rf.list$results
# Out:
#     biome cluster rf.Ntree rf.RMSE   rf.bias     rf.RVar    rf.cor.pvalue
# 2   1      1       40       6.923923 0.011146382 0.07221510 0.27303227
# 3   1      2       60       9.809538 0.008495670 0.08001752 0.16823756
# 4   1      3      100      26.437511 0.028500140 0.04678618 0.27517894
# 5   1      4       NA             NA          NA         NA         NA
# 6   1      5       NA             NA          NA         NA         NA
# 7   1      6       60      17.223881 0.006713675 0.05679778 0.76399168
# 8   1      7       80      26.140957 0.021726355 0.08155227 0.88824266
# 9   1      8       10      14.085509 0.009272694 0.05696911 0.76026827
# 10  1      9       10      13.450097 0.007033910 0.11493326 0.45985220
# 11  1     10      100      18.129625 0.007673480 0.03559035 0.79720861
# 12  1     11       40      22.441454 0.028702032 0.09927226 0.24281852
# 13  1     12       NA             NA          NA         NA         NA
# ...

# %%
knn.list <- knn.all(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), mode = 'unimodal', t = 2)

# %%
knn.list$results
# Out:
#     biome cluster knn.RMSE  knn.bias    knn.RVar   knn.cor.pvalue knn.cor
# 2   1      1      10.504705 0.011160698 1.6523098  0.4174244948    0.197602610
# 3   1      2      15.062319 0.008495209 1.7560387  0.3121649615    0.244939970
# 4   1      3      39.533406 0.027433484 1.0210693  0.2710116012   -0.266000640
# 5   1      4             NA          NA        NA            NA             NA
# 6   1      5             NA          NA        NA            NA             NA
# 7   1      6      21.226142 0.006613187 1.2214273  0.1989466361    0.308388276
# 8   1      7      26.690693 0.020099697 0.6514336  0.1040331865    0.384542609
# 9   1      8      17.204779 0.008850653 0.7405021  0.5190841303    0.157693244
# 10  1      9      25.794169 0.007010961 1.4572695  0.0288949675   -0.500973560
# 11  1     10      24.942254 0.007471572 1.0422505  0.7328246462    0.081450329
# 12  1     11      34.775140 0.027173418 1.2700382  0.1877543369   -0.315835003
# ...

# %%
table = cbind(lm.list$results, rf.list$results[,-c(1,2)], knn.list$results[,-c(1,2)])
table
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1       1        6.839691 0.011179855 0.2659278 0.147122165
# 3   1      2       2        9.362343 0.008462079 0.3504922 0.050994782
# 4   1      3       0              NA          NA        NA          NA
# 5   1      4      NA              NA          NA        NA          NA
# 6   1      5      NA              NA          NA        NA          NA
# 7   1      6       3       14.584997 0.006764675 0.5742464 0.013585201
# 8   1      7       3       23.442196 0.021424566 0.5132260 0.047067758
# 9   1      8       0              NA          NA        NA          NA
# 10  1      9       0              NA          NA        NA          NA
# 11  1     10       2       16.815977 0.007856959 0.4794496 0.055687664
# 12  1     11       0              NA          NA        NA          NA
# 13  1     12      NA              NA          NA        NA          NA
# ...

# %%
# Clusters that have a linear, a random forest and a knn models
table1 <- table[-which(is.na(table$lm.RMSE)),]
table1
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1      1         6.839691 0.011179855 0.2659278 0.147122165
# 3   1      2      2         9.362343 0.008462079 0.3504922 0.050994782
# 7   1      6      3        14.584997 0.006764675 0.5742464 0.013585201
# 8   1      7      3        23.442196 0.021424566 0.5132260 0.047067758
# 11  1     10      2        16.815977 0.007856959 0.4794496 0.055687664
# 14  1     13      1        21.262815 0.015197798 0.3111555 0.092844703
# 16  2      1      3        15.130435 0.035628780 0.4813301 0.107933270
# 18  2      3      3         7.356102 0.015229703 0.5553172 0.005830976
# 19  2      4      3        10.837578 0.011534049 0.3463296 0.066805067
# 20  2      5      3        11.838434 0.013380660 0.6374363 0.017461020
# 21  2      6      3        26.236928 0.033142959 0.5759215 0.008869092
# 24  3      3      1        30.966490 0.039770570 0.4895642 0.011065519
# ...

# %%
colMeans(table1[,-c(1,2,3,12)])
# Out:
#        lm.RMSE        lm.bias        lm.RVar  lm.cor.pvalue         lm.cor
#    42.01581489     0.90417271     0.45774249     0.14118337     0.40795859
#         lm.acc      lm.acc.t1      lm.acc.t2       rf.Ntree        rf.RMSE
#     0.47745528     0.49509804     0.35784314    74.26470588    44.26807489
#        rf.bias        rf.RVar  rf.cor.pvalue         rf.cor         rf.acc
#     0.93080274     0.07087581     0.44987562     0.10940510     0.36103371
#      rf.acc.t1      rf.acc.t2      rf.acc.t3       knn.RMSE       knn.bias
#     0.33193277     0.30147059     0.43802521    58.28807497     0.70301595
#       knn.RVar knn.cor.pvalue        knn.cor        knn.acc     knn.acc.t1
#     0.88157222     0.47260793     0.05991368     0.34025628     0.28956583
#     knn.acc.t2     knn.acc.t3
#     0.30147059     0.41771709

# %%
table.lag.2 <- table
save(table.lag.2, file = 'ModelData/models_results_per_cluster_without_delta_lag2.Rdata')
#model.no.deltas.Lag.2 = list('lm' = lm.list, 'rf' = rf.list, 'knn' = knn.list)
#save(model.no.deltas.Lag.2, file = 'ModelData/models_without_delta_lag_2')

# %% [markdown]
# ## With 3-months persistence

# %%
lm.list <- lm.all(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                  cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), mode = 'unimodal', t = 3)

# %%
lm.list$results
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1       2        6.798426 0.011187541 0.3320369 0.112350317
# 3   1      2       4        9.691607 0.008489774 0.4046803 0.074580419
# 4   1      3       0              NA          NA        NA          NA
# 5   1      4      NA              NA          NA        NA          NA
# 6   1      5      NA              NA          NA        NA          NA
# 7   1      6       4       15.454416 0.006774764 0.6237481 0.026581441
# 8   1      7       4       22.212977 0.021419918 0.6650887 0.014388560
# 9   1      8       1       13.202221 0.009305526 0.2334746 0.245174263
# 10  1      9       0              NA          NA        NA          NA
# 11  1     10       4       19.681891 0.007907573 0.8070818 0.144713394
# 12  1     11       0              NA          NA        NA          NA
# 13  1     12      NA              NA          NA        NA          NA
# ...

# %%
rf.list <- rf.all(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                  cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), mode = 'unimodal', t = 3)

# %%
rf.list$results
# Out:
#     biome cluster rf.Ntree rf.RMSE   rf.bias     rf.RVar    rf.cor.pvalue
# 2   1      1       40       7.063821 0.011047108 0.03666939 0.30352324
# 3   1      2      140       9.926009 0.008486257 0.07378418 0.22463031
# 4   1      3       20      25.589094 0.028879855 0.06501974 0.83198532
# 5   1      4       NA             NA          NA         NA         NA
# 6   1      5       NA             NA          NA         NA         NA
# 7   1      6       20      16.905402 0.006759231 0.10848641 0.44078881
# 8   1      7      160      25.410739 0.021666076 0.06578094 0.62108725
# 9   1      8      200      14.075199 0.009349918 0.03139867 0.44885761
# 10  1      9      160      14.516233 0.006995642 0.04800049 0.28597375
# 11  1     10       10      17.439189 0.007627629 0.08085614 0.25399926
# 12  1     11      100      22.392640 0.028537464 0.06773706 0.10218183
# 13  1     12       NA             NA          NA         NA         NA
# ...

# %%
knn.list <- knn.all(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                  cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), mode = 'unimodal', t = 3)

# %%
knn.list$results
# Out:
#     biome cluster knn.RMSE  knn.bias    knn.RVar   knn.cor.pvalue knn.cor
# 2   1      1      10.542988 0.011291482 1.8651260  0.27369649      0.26456898
# 3   1      2      15.384279 0.008240272 1.6547235  0.39238681      0.20818914
# 4   1      3      39.429138 0.027464338 0.9001327  0.15335039     -0.34079338
# 5   1      4             NA          NA        NA          NA              NA
# 6   1      5             NA          NA        NA          NA              NA
# 7   1      6      26.958112 0.006384810 1.6123170  0.74216646      0.08083894
# 8   1      7      32.699620 0.021174688 0.7799034  0.77453332      0.07041506
# 9   1      8      16.606549 0.008789163 0.8211627  0.24631374      0.27960815
# 10  1      9      25.410854 0.007149950 1.4542952  0.05742977     -0.44309754
# 11  1     10      23.382170 0.008181324 0.7004346  0.85867234      0.04253753
# 12  1     11      37.279648 0.026907584 1.6047454  0.18462164     -0.31797231
# ...

# %%
table = cbind(lm.list$results, rf.list$results[,-c(1,2)], knn.list$results[,-c(1,2)])
table
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1       2        6.798426 0.011187541 0.3320369 0.112350317
# 3   1      2       4        9.691607 0.008489774 0.4046803 0.074580419
# 4   1      3       0              NA          NA        NA          NA
# 5   1      4      NA              NA          NA        NA          NA
# 6   1      5      NA              NA          NA        NA          NA
# 7   1      6       4       15.454416 0.006774764 0.6237481 0.026581441
# 8   1      7       4       22.212977 0.021419918 0.6650887 0.014388560
# 9   1      8       1       13.202221 0.009305526 0.2334746 0.245174263
# 10  1      9       0              NA          NA        NA          NA
# 11  1     10       4       19.681891 0.007907573 0.8070818 0.144713394
# 12  1     11       0              NA          NA        NA          NA
# 13  1     12      NA              NA          NA        NA          NA
# ...

# %%
# Clusters that have a linear, a random forest and a knn models
table1 <- table[-which(is.na(table$lm.RMSE)),]
table1
# Out:
#     biome cluster lm.Npred lm.RMSE   lm.bias     lm.RVar   lm.cor.pvalue
# 2   1      1      2         6.798426 0.011187541 0.3320369 0.112350317
# 3   1      2      4         9.691607 0.008489774 0.4046803 0.074580419
# 7   1      6      4        15.454416 0.006774764 0.6237481 0.026581441
# 8   1      7      4        22.212977 0.021419918 0.6650887 0.014388560
# 9   1      8      1        13.202221 0.009305526 0.2334746 0.245174263
# 11  1     10      4        19.681891 0.007907573 0.8070818 0.144713394
# 14  1     13      2        19.943342 0.015148242 0.4101676 0.027570504
# 16  2      1      3        15.130435 0.035628780 0.4813301 0.107933270
# 17  2      2      1        15.044841 0.013524199 0.2826946 0.201852806
# 18  2      3      4         7.322230 0.015216314 0.6019993 0.004854506
# 19  2      4      3        10.837578 0.011534049 0.3463296 0.066805067
# 20  2      5      5        13.173007 0.013442379 0.8049471 0.041615336
# ...

# %%
colMeans(table1[,-c(1,2,3,12)])
# Out:
#        lm.RMSE        lm.bias        lm.RVar  lm.cor.pvalue         lm.cor
#    43.47202073     0.92681292     0.48762731     0.13069887     0.41371890
#         lm.acc      lm.acc.t1      lm.acc.t2       rf.Ntree        rf.RMSE
#     0.49056248     0.50501253     0.36842105    75.39473684    45.88931269
#        rf.bias        rf.RVar  rf.cor.pvalue         rf.cor         rf.acc
#     0.96844762     0.06539754     0.44021135     0.09381887     0.34794552
#      rf.acc.t1      rf.acc.t2      rf.acc.t3       knn.RMSE       knn.bias
#     0.33615288     0.30701754     0.39285714    60.08484759     0.71825990
#       knn.RVar knn.cor.pvalue        knn.cor        knn.acc     knn.acc.t1
#     0.84447780     0.54494392     0.05816786     0.33710372     0.26002506
#     knn.acc.t2     knn.acc.t3
#     0.33114035     0.41008772

# %%
table.lag.3 <- table
save(table.lag.3, file = 'ModelData/models_results_per_cluster_without_delta_lag3.Rdata')
#model.no.deltas.Lag.3 = list('lm' = lm.list, 'rf' = rf.list, 'knn' = knn.list)
#save(model.no.deltas.Lag.3, file = 'ModelData/models_without_delta_lag_3')

# %% [markdown]
# ## Finding the optimum number of trees
#
# This is a brief study about the optimum number of trees of the random forest models.

# %%
rf <- rf.obtention.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 5, 1, t=2)
# Out:
# Plot with title "acc"

# %%
rf <- rf.obtention.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 7, 6, t=2)
# Out:
# Plot with title "acc"

# %%
rf <- rf.obtention.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 11, 15, t=2)
# Out:
# Plot with title "acc"

# %%
# malos
rf <- rf.obtention.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 5, 2, t=2)
# Out:
# Plot with title "acc"

# %%
rf <- rf.obtention.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 11, 19, t=2)
# Out:
# Plot with title "acc"

# %%
rf <- rf.obtention.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates, cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 7, 6, t=2)
# Out:
# Plot with title "acc"

# %% [markdown]
# # Using trees
#
# We show some regression trees of some clusters where linear models with 3-months persistence did not have a good performance

# %%
# Biome 13, cluster 6, persistence of 3 months
t = tree.obtention(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                 cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list('nina34'=nina34, 'nao'=nao, 'pol'=poleur, 'ea'=ea, 'eawr'=eawr, 'pna'=pna, 'scand'=scand, 'wp'=wp), 13,
                   6, t=3)
# Out:
#         RMSE       bias     RVar   cor.pvalue       cor       acc    acc.t1
# cor 6.757999 0.01216393 0.870818 7.625363e-09 0.9307116 0.7894737 0.6666667
#        acc.t2    acc.t3
# cor 0.8333333 0.8571429
# Minsize = 2 Mindev = 0.05
# plot without title

# %%
# Biome 1, cluster 8, persistence of 3 months
t = tree.obtention(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                 cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list('nina34'=nina34, 'nao'=nao, 'pol'=poleur, 'ea'=ea, 'eawr'=eawr, 'pna'=pna, 'scand'=scand, 'wp'=wp), 1, 8,
                   t=3)
# Out:
#         RMSE        bias      RVar   cor.pvalue      cor       acc    acc.t1
# cor 1.832007 0.009370155 0.9813529 3.734519e-16 0.990663 0.8947368 0.6666667
#     acc.t2 acc.t3
# cor      1      1
# Minsize = 2 Mindev = 0.01
# plot without title

# %%
# Biome 5, cluster 2, persistence of 3 months
t = tree.obtention(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                 cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list('nina34'=nina34, 'nao'=nao, 'pol'=poleur, 'ea'=ea, 'eawr'=eawr, 'pna'=pna, 'scand'=scand, 'wp'=wp), 5, 2,
                   t=3)
# Out:
#         RMSE      bias      RVar  cor.pvalue       cor       acc acc.t1 acc.t2
# cor 22.24579 0.1474667 0.4415211 0.001954931 0.6634797 0.4736842      0    0.5
#        acc.t3
# cor 0.8571429
# Minsize = 2 Mindev = 0.25
# plot without title

# %%
# Biome 7, cluster 3, persistence of 3 months
t = tree.obtention(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                 cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list('nina34'=nina34, 'nao'=nao, 'pol'=poleur, 'ea'=ea, 'eawr'=eawr, 'pna'=pna, 'scand'=scand, 'wp'=wp), 7, 3,
                   t=3)
# Out:
#         RMSE        bias     RVar   cor.pvalue       cor       acc    acc.t1
# cor 3.298748 0.002119028 0.920609 1.146576e-10 0.9581797 0.6842105 0.3333333
#        acc.t2    acc.t3
# cor 0.8333333 0.8571429
# Minsize = 5 Mindev = 0.01
# plot without title

# %% [markdown]
# # Comparison of 3 clusters between modelling using delta data or without using it
#
# Now, we show the performance of the linear models that have been trained without delta data in 3 clusters. In the notebook *Modelling_with_deltas.ipynb* we can see the linear models for the same clusters but these models have used the delta time series.
#
# ## Biome 1, cluster 7, 3-months persistence

# %%
t = lm.clus.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                 cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 1, 7, t=3)
# Out:
#         RMSE       bias      RVar cor.pvalue       cor       acc acc.t1
# cor 22.21298 0.02141992 0.6650887 0.01438856 0.5514364 0.4210526    0.5
#        acc.t2    acc.t3
# cor 0.1666667 0.5714286
# Plot with title "Observed vs predicted"

# %% [markdown]
# ## Biome 4, cluster 3, 3-months persistence

# %%
t = lm.clus.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                 cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 4, 3, t=3)
# Out:
#         RMSE        bias      RVar cor.pvalue       cor       acc    acc.t1
# cor 17.78682 0.004162922 0.6534614 0.01323769 0.5570009 0.5789474 0.6666667
#        acc.t2    acc.t3
# cor 0.3333333 0.7142857
# Plot with title "Observed vs predicted"

# %% [markdown]
# ## Biome 12, cluster 4, 3-months persistence
#
# This clusters includes the Iberian Peninsula

# %%
t = lm.clus.plot(fireSeasonPer75_def, log1p(masked_ba_series), dates,
                 cbind(corr.df, corr.df.lag.1[,-c(1,2)], corr.df.lag.2[,-c(1,2)], corr.df.lag.3[,-c(1,2)]), 
                  list(nina34, nao, poleur, ea, eawr, pna, scand, wp), 12, 4, t=3)
# Out:
#         RMSE       bias      RVar cor.pvalue       cor       acc acc.t1
# cor 17.80448 0.05838634 0.4927275  0.2366537 0.2851656 0.4210526    0.5
#        acc.t2    acc.t3
# cor 0.3333333 0.4285714
# Plot with title "Observed vs predicted"

# %% [markdown]
# # General results of the models
#
# Using the models without deltas with 3-months persistence

# %%
load('ModelData/models_results_per_cluster_without_delta_lag3.Rdata', verbose = T)
# Out:
# Loading objects:
#   table.lag.3

# %%
table <- table.lag.3

plot(table$biome, apply(cbind(table$lm.RMSE, table$rf.RMSE, table$knn.RMSE), 1, max, T), type = 'n', xlab = 'Biome', 
     ylab = 'RMSE', main = 'RMSE without deltas')
points(table$biome, table$lm.RMSE, pch = 1, col = table$cluster)
points(table$biome, table$rf.RMSE, pch = 0, col = table$cluster)
points(table$biome, table$knn.RMSE, pch = 6, col = table$cluster)
legend(1, max(apply(cbind(table$lm.RMSE, table$rf.RMSE, table$knn.RMSE), 1, max, T), na.rm = T), legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))
# Out:
# Plot with title "RMSE without deltas"

# %%
plot(table$biome, c(rep(8, length(table$biome)-1),0), type = 'n', xlab = 'Biome', 
     ylab = 'Bias', main = 'Bias without deltas')
points(table$biome, table$lm.bias, pch = 1, col = table$cluster)
points(table$biome, table$rf.bias, pch = 0, col = table$cluster)
points(table$biome, table$knn.bias, pch = 6, col = table$cluster)
legend(1, 8, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))


plot(table$biome, c(rep(1, length(table$biome)-1),0), type = 'n', xlab = 'Biome', 
     ylab = 'Bias', main = 'Bias without deltas (zoom)')
points(table$biome, table$lm.bias, pch = 1, col = table$cluster)
points(table$biome, table$rf.bias, pch = 0, col = table$cluster)
points(table$biome, table$knn.bias, pch = 6, col = table$cluster)
legend(1, 1, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))
# Out:
# Plot with title "Bias without deltas"
# Plot with title "Bias without deltas (zoom)"

# %%
plot(table$biome, c(rep(1, length(table$biome)-1),0), type = 'n', xlab = 'Biome', 
     ylab = 'p-value', main = 'Correlation p-value without deltas')
points(table$biome, table$lm.cor.pvalue, pch = 1, col = table$cluster)
points(table$biome, table$rf.cor.pvalue, pch = 0, col = table$cluster)
points(table$biome, table$knn.cor.pvalue, pch = 6, col = table$cluster)
legend(3, 1, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))

plot(table$biome, c(rep(1, length(table$biome)-1),-1), type = 'n', xlab = 'Biome', 
     ylab = 'Corr', main = 'Correlation without deltas')
points(table$biome, table$lm.cor, pch = 1, col = table$cluster)
points(table$biome, table$rf.cor, pch = 0, col = table$cluster)
points(table$biome, table$knn.cor, pch = 6, col = table$cluster)
legend(1, -0.6, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))
# Out:
# Plot with title "Correlation p-value without deltas"
# Plot with title "Correlation without deltas"

# %%
plot(table$biome, c(rep(2, length(table$biome)-1),0), type = 'n', xlab = 'Biome', 
     ylab = 'Ratio of variance', main = 'Ratio of variance without deltas')
points(table$biome, table$lm.RVar, pch = 1, col = table$cluster)
points(table$biome, table$rf.RVar, pch = 0, col = table$cluster)
points(table$biome, table$knn.RVar, pch = 6, col = table$cluster)
legend(11.5, 2, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))
# Out:
# Plot with title "Ratio of variance without deltas"

# %%
plot(table$biome, c(rep(1, length(table$biome)-1),0), type = 'n', xlab = 'Biome', 
     ylab = 'General accuracy', main = 'General accuracy without deltas')
points(table$biome, table$lm.acc, pch = 1, col = table$cluster)
points(table$biome, table$rf.acc, pch = 0, col = table$cluster)
points(table$biome, table$knn.acc, pch = 6, col = table$cluster)
legend(11.5, 1, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))


plot(table$biome, c(rep(1, length(table$biome)-1),0), type = 'n', xlab = 'Biome', 
     ylab = 'First tercile accuracy', main = 'First tercile accuracy without deltas')
points(table$biome, table$lm.acc.t1, pch = 1, col = table$cluster)
points(table$biome, table$rf.acc.t1, pch = 0, col = table$cluster)
points(table$biome, table$knn.acc.t1, pch = 6, col = table$cluster)
legend(11.5, 1, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))


plot(table$biome, c(rep(1, length(table$biome)-1),0), type = 'n', xlab = 'Biome', 
     ylab = 'Second tercile accuracy', main = 'Second tercile accuracy without deltas')
points(table$biome, table$lm.acc.t2, pch = 1, col = table$cluster)
points(table$biome, table$rf.acc.t2, pch = 0, col = table$cluster)
points(table$biome, table$knn.acc.t2, pch = 6, col = table$cluster)
legend(11.5, 1, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))


plot(table$biome, c(rep(1, length(table$biome)-1),0), type = 'n', xlab = 'Biome', 
     ylab = 'Third tercile accuracy', main = 'Third tercile accuracy without deltas')
points(table$biome, table$lm.acc.t3, pch = 1, col = table$cluster)
points(table$biome, table$rf.acc.t3, pch = 0, col = table$cluster)
points(table$biome, table$knn.acc.t3, pch = 6, col = table$cluster)
legend(11.5, 1, legend=c("lm", "rf", "knn"),
       pch=c(1, 0, 6))
# Out:
# Plot with title "General accuracy without deltas"
# Plot with title "First tercile accuracy without deltas"
# Plot with title "Second tercile accuracy without deltas"
# Plot with title "Third tercile accuracy without deltas"
